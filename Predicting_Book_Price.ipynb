# %%
import pandas as pd

# %%
url = r"D:\My Work\Otherthan Syllabus\Data Science\Projects\Predicting_Book_Price\Participants_Data\Data.xlsx"

# %%
file = pd.ExcelFile(url)

# %%
df_data = file.parse(0)

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition             Reviews              Ratings  \
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
df_data[df_data.isnull().any(axis=1)].count()
# Out:
# Title           0
# Author          0
# Edition         0
# Reviews         0
# Ratings         0
# Synopsis        0
# Genre           0
# BookCategory    0
# Price           0
# dtype: int64

# %%
df_data.drop(['Synopsis'],axis=1,inplace=True)

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition             Reviews              Ratings  \
# ...

# %%
df_data.dtypes
# Out:
# Title            object
# Author           object
# Edition          object
# Reviews          object
# Ratings          object
# Genre            object
# BookCategory     object
# Price           float64
# dtype: object

# %%
df_data.describe(include='all')
# Out:
#                                              Title           Author  \
# count                                         6237             6237
# unique                                        5568             3679
# top     A Game of Thrones (A Song of Ice and Fire)  Agatha Christie
# freq                                             4               69
# mean                                           NaN              NaN
# std                                            NaN              NaN
# min                                            NaN              NaN
# 25%                                            NaN              NaN
# 50%                                            NaN              NaN
# 75%                                            NaN              NaN
# max                                            NaN              NaN
#
#                        Edition             Reviews            Ratings  \
# count                     6237                6237               6237
# ...

# %%
df_data['Reviews'] = df_data['Reviews'].map(lambda x: x.lstrip('+-').rstrip('out of 5 stars'))

# %%
df_data['Reviews'] = df_data['Reviews'].astype(float)

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews              Ratings  \
# ...

# %%
df_data['Ratings'] = df_data['Ratings'].map(lambda x: x.lstrip('+-').rstrip('customer reviews'))

# %%
df_data['Ratings']
# Out:
# 0        8
# 1       14
# 2        6
# 3       13
# 4        1
#         ..
# 6232     2
# 6233     9
# 6234     3
# 6235     4
# 6236     2
# Name: Ratings, Length: 6237, dtype: object

# %%
df_data['Ratings'] = df_data['Ratings'].astype(int)

# %%
df_data.dtypes
# Out:
# Title            object
# Author           object
# Edition          object
# Reviews         float64
# Ratings           int32
# Genre            object
# BookCategory     object
# Price           float64
# dtype: object

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews  Ratings                         Genre  \
# ...

# %%
headers = ['Title', 'Author','Edition', 'Reviews out of 5','Ratings (customer reviews)','Genre','Book_Category','Price']
df_data.columns = headers

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# ...

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df_data['Genre_encode'] = label_encoder.fit_transform(df_data['Genre'].astype(str))

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# ...

# %%
df_data['Book_Category_encode'] = label_encoder.fit_transform(df_data['Book_Category'].astype(str))

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# ...

# %%
df_data['Title_encode'] = label_encoder.fit_transform(df_data['Title'].astype(str))

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# ...

# %%
df_data['Author_encode'] = label_encoder.fit_transform(df_data['Author'].astype(str))

# %%
df_data
# Out:
#                                                   Title           Author  \
# 0                   The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1                    Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                          Leviathan (Penguin Classics)    Thomas Hobbes
# 3                    A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4            LIFE 70 Years of Extraordinary Photography  Editors of Life
# ...                                                 ...              ...
# 6232  Humans: A Brief History of How We F*cked It Al...     Tom Phillips
# 6233                                        The Chemist  Stephenie Meyer
# 6234  The Duke And I: Number 1 in series (Bridgerton...      Julia Quinn
# 6235                       Frostfire (Kanin Chronicles)   Amanda Hocking
# 6236                        The First Order (Sam Capra)      Jeff Abbott
#
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# ...

# %%
title_arr = df_data['Title'].values
title_encode_arr = df_data['Title_encode'].values
title_df = pd.DataFrame(title_arr)
title_encode_df = pd.DataFrame(title_encode_arr)
df_title = pd.concat([title_df, title_encode_df], axis=1)
df_title.columns = ['Title', 'Title encode']
df_title
# Out:
#                                                   Title  Title encode
# 0                   The Prisoner's Gold (The Hunters 3)          4763
# 1                    Guru Dutt: A Tragedy in Three Acts          1721
# 2                          Leviathan (Penguin Classics)          2446
# 3                    A Pocket Full of Rye (Miss Marple)           155
# 4            LIFE 70 Years of Extraordinary Photography          2343
# ...                                                 ...           ...
# 6232  Humans: A Brief History of How We F*cked It Al...          1948
# 6233                                        The Chemist          4129
# 6234  The Duke And I: Number 1 in series (Bridgerton...          4264
# 6235                       Frostfire (Kanin Chronicles)          1559
# 6236                        The First Order (Sam Capra)          4325
#
# [6237 rows x 2 columns]

# %%
author_arr = df_data['Author'].values
author_encode_arr = df_data['Author_encode'].values
author_df = pd.DataFrame(author_arr)
author_encode_df = pd.DataFrame(author_encode_arr)
df_author = pd.concat([author_df, author_encode_df], axis=1)
df_author.columns = ['Author', 'Author encode']
df_author
# Out:
#                Author  Author encode
# 0      Chris Kuzneski            615
# 1        Arun Khopkar            307
# 2       Thomas Hobbes           3390
# 3     Agatha Christie             62
# 4     Editors of Life            953
# ...               ...            ...
# 6232     Tom Phillips           3441
# 6233  Stephenie Meyer           3211
# 6234      Julia Quinn           1692
# 6235   Amanda Hocking            144
# 6236      Jeff Abbott           1483
#
# [6237 rows x 2 columns]

# %%
genre_arr = df_data['Genre'].values
genre_encode_arr = df_data['Genre_encode'].values
genre_df = pd.DataFrame(genre_arr)
genre_encode_df = pd.DataFrame(genre_encode_arr)
df_genre = pd.concat([genre_df, genre_encode_df], axis=1)
df_genre.columns = ['Genre', 'Genre encode']
df_genre
# Out:
#                              Genre  Genre encode
# 0       Action & Adventure (Books)             1
# 1       Cinema & Broadcast (Books)            74
# 2          International Relations           193
# 3     Contemporary Fiction (Books)            92
# 4            Photography Textbooks           253
# ...                            ...           ...
# 6232          Anthropology (Books)            17
# 6233  Contemporary Fiction (Books)            92
# 6234               Romance (Books)           282
# 6235    Action & Adventure (Books)             1
# 6236    Action & Adventure (Books)             1
#
# [6237 rows x 2 columns]

# %%
book_category_arr = df_data['Book_Category'].values
book_category_encode_arr = df_data['Book_Category_encode'].values
book_category_df = pd.DataFrame(book_category_arr)
book_category_encode_df = pd.DataFrame(book_category_encode_arr)
df_book_category = pd.concat([book_category_df, book_category_encode_df], axis=1)
df_book_category.columns = ['Book_Category', 'Book_Category_encode']
df_book_category
# Out:
#                              Book_Category  Book_Category_encode
# 0                       Action & Adventure                     0
# 1     Biographies, Diaries & True Accounts                     2
# 2                                   Humour                     6
# 3                Crime, Thriller & Mystery                     5
# 4                 Arts, Film & Photography                     1
# ...                                    ...                   ...
# 6232                                Humour                     6
# 6233             Crime, Thriller & Mystery                     5
# 6234                               Romance                     9
# 6235                    Action & Adventure                     0
# 6236                    Action & Adventure                     0
#
# [6237 rows x 2 columns]

# %%
df_data.drop(['Title','Author','Genre', 'Book_Category'], axis=1, inplace=True)
df_data
# Out:
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# 0     Paperback,– 10 Mar 2016               4.0                           8
# 1      Paperback,– 7 Nov 2012               3.9                          14
# 2     Paperback,– 25 Feb 1982               4.8                           6
# 3      Paperback,– 5 Oct 2017               4.1                          13
# 4     Hardcover,– 10 Oct 2006               5.0                           1
# ...                       ...               ...                         ...
# 6232   Paperback,– 8 Aug 2018               5.0                           2
# 6233  Paperback,– 21 Nov 2016               3.3                           9
# 6234   Paperback,– 8 Jun 2006               3.8                           3
# 6235  Paperback,– 15 Jan 2015               3.0                           4
# 6236  Paperback,– 21 Dec 2016               3.9                           2
#
# ...

# %%
len(df_data['Edition'].unique())
# Out:
# 3370

# %%
df_data[['Edition_Type', 'Edition_Date']] = df_data['Edition'].str.split(",",n=1, expand=True)
df_data
# Out:
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# 0     Paperback,– 10 Mar 2016               4.0                           8
# 1      Paperback,– 7 Nov 2012               3.9                          14
# 2     Paperback,– 25 Feb 1982               4.8                           6
# 3      Paperback,– 5 Oct 2017               4.1                          13
# 4     Hardcover,– 10 Oct 2006               5.0                           1
# ...                       ...               ...                         ...
# 6232   Paperback,– 8 Aug 2018               5.0                           2
# 6233  Paperback,– 21 Nov 2016               3.3                           9
# 6234   Paperback,– 8 Jun 2006               3.8                           3
# 6235  Paperback,– 15 Jan 2015               3.0                           4
# 6236  Paperback,– 21 Dec 2016               3.9                           2
#
# ...

# %%
df_data['Edition_Type'].unique()
# Out:
# array(['Paperback', 'Hardcover', 'Mass Market Paperback', 'Sheet music',
#        'Flexibound', 'Plastic Comb', 'Loose Leaf', 'Tankobon Softcover',
#        'Perfect Paperback', 'Board book', 'Cards', 'Spiral-bound',
#        '(Kannada)', 'Product Bundle', 'Library Binding', '(German)',
#        'Leather Bound', '(French)', '(Spanish)'], dtype=object)

# %%
df_data['Edition_Type_encode'] = label_encoder.fit_transform(df_data['Edition_Type'].astype(str))
df_data
# Out:
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# 0     Paperback,– 10 Mar 2016               4.0                           8
# 1      Paperback,– 7 Nov 2012               3.9                          14
# 2     Paperback,– 25 Feb 1982               4.8                           6
# 3      Paperback,– 5 Oct 2017               4.1                          13
# 4     Hardcover,– 10 Oct 2006               5.0                           1
# ...                       ...               ...                         ...
# 6232   Paperback,– 8 Aug 2018               5.0                           2
# 6233  Paperback,– 21 Nov 2016               3.3                           9
# 6234   Paperback,– 8 Jun 2006               3.8                           3
# 6235  Paperback,– 15 Jan 2015               3.0                           4
# 6236  Paperback,– 21 Dec 2016               3.9                           2
#
# ...

# %%
edition_type_arr = df_data['Edition_Type'].values
edition_type_encode_arr = df_data['Edition_Type_encode'].values
edition_type_df = pd.DataFrame(edition_type_arr)
edition_type_encode_df = pd.DataFrame(edition_type_encode_arr)
df_edition_type = pd.concat([edition_type_df, edition_type_encode_df], axis=1)
df_edition_type.columns = ['Edition_Type', 'Edition_Type_encode']
df_edition_type
# Out:
#      Edition_Type  Edition_Type_encode
# 0       Paperback                   12
# 1       Paperback                   12
# 2       Paperback                   12
# 3       Paperback                   12
# 4       Hardcover                    7
# ...           ...                  ...
# 6232    Paperback                   12
# 6233    Paperback                   12
# 6234    Paperback                   12
# 6235    Paperback                   12
# 6236    Paperback                   12
#
# [6237 rows x 2 columns]

# %%
df_data[['0','Edition_Date']] = df_data['Edition_Date'].str.split(" ",n=1, expand=True)
df_data
# Out:
#                       Edition  Reviews out of 5  Ratings (customer reviews)  \
# 0     Paperback,– 10 Mar 2016               4.0                           8
# 1      Paperback,– 7 Nov 2012               3.9                          14
# 2     Paperback,– 25 Feb 1982               4.8                           6
# 3      Paperback,– 5 Oct 2017               4.1                          13
# 4     Hardcover,– 10 Oct 2006               5.0                           1
# ...                       ...               ...                         ...
# 6232   Paperback,– 8 Aug 2018               5.0                           2
# 6233  Paperback,– 21 Nov 2016               3.3                           9
# 6234   Paperback,– 8 Jun 2006               3.8                           3
# 6235  Paperback,– 15 Jan 2015               3.0                           4
# 6236  Paperback,– 21 Dec 2016               3.9                           2
#
# ...

# %%
df_data.drop(['Edition', 'Edition_Type','0'], axis=1, inplace=True)
df_data
# Out:
#       Reviews out of 5  Ratings (customer reviews)   Price  Genre_encode  \
# 0                  4.0                           8  220.00             1
# 1                  3.9                          14  202.93            74
# 2                  4.8                           6  299.00           193
# 3                  4.1                          13  180.00            92
# 4                  5.0                           1  965.62           253
# ...                ...                         ...     ...           ...
# 6232               5.0                           2  322.00            17
# 6233               3.3                           9  421.00            92
# 6234               3.8                           3  399.00           282
# 6235               3.0                           4  319.00             1
# 6236               3.9                           2  452.00             1
#
#       Book_Category_encode  Title_encode  Author_encode Edition_Date  \
# ...

# %%
df_data.dtypes
# Out:
# Reviews out of 5              float64
# Ratings (customer reviews)      int32
# Price                         float64
# Genre_encode                    int32
# Book_Category_encode            int32
# Title_encode                    int32
# Author_encode                   int32
# Edition_Date                   object
# Edition_Type_encode             int32
# dtype: object

# %%
df_data[['Edition_Day','Edition_Month','Edition_Year']] = df_data['Edition_Date'].str.split(" ",n=2, expand=True)
df_data
# Out:
#       Reviews out of 5  Ratings (customer reviews)   Price  Genre_encode  \
# 0                  4.0                           8  220.00             1
# 1                  3.9                          14  202.93            74
# 2                  4.8                           6  299.00           193
# 3                  4.1                          13  180.00            92
# 4                  5.0                           1  965.62           253
# ...                ...                         ...     ...           ...
# 6232               5.0                           2  322.00            17
# 6233               3.3                           9  421.00            92
# 6234               3.8                           3  399.00           282
# 6235               3.0                           4  319.00             1
# 6236               3.9                           2  452.00             1
#
#       Book_Category_encode  Title_encode  Author_encode Edition_Date  \
# ...

# %%
df_data.drop(['Edition_Date'],axis=1,inplace=True)
df_data
# Out:
#       Reviews out of 5  Ratings (customer reviews)   Price  Genre_encode  \
# 0                  4.0                           8  220.00             1
# 1                  3.9                          14  202.93            74
# 2                  4.8                           6  299.00           193
# 3                  4.1                          13  180.00            92
# 4                  5.0                           1  965.62           253
# ...                ...                         ...     ...           ...
# 6232               5.0                           2  322.00            17
# 6233               3.3                           9  421.00            92
# 6234               3.8                           3  399.00           282
# 6235               3.0                           4  319.00             1
# 6236               3.9                           2  452.00             1
#
#       Book_Category_encode  Title_encode  Author_encode  Edition_Type_encode  \
# ...

# %%
edition_day_arr = df_data['Edition_Day'].values
edition_year_arr = df_data['Edition_Year'].values
print(edition_day_arr)
print(edition_year_arr)
# Out:
# ['10' '7' '25' ... '8' '15' '21']
# ['2016' '2012' '1982' ... '2006' '2015' '2016']

# %%
new_edition_day_arr = []
for value in edition_day_arr:
    try:
        value = int(value)
        new_edition_day_arr.append(value)
    except:
        print(f"Error in {value}")
print(new_edition_day_arr)
print(len(new_edition_day_arr))
# Out:
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Deckle
# Error in Box
# Error in Import,
# Error in Import,
# Error in Import,
# Error in International
# Error in Import,
# Error in Unabridged,
# Error in Special
# Error in International
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Student
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Jan
# Error in Illustrated,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Abridged,
# Error in Apr
# Error in Import,
# Error in Import,
# Error in Unabridged,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Illustrated,
# Error in Special
# Error in DVD,
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Bargain
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Deckle
# Error in Import,
# Error in Import,
# Error in Import,
# Error in Import,
# ...

# %%
df_data['Edition_Day'].loc[df_data['Edition_Day'] == 'Apr']
# Out:
# 171     Apr
# 2227    Apr
# 4332    Apr
# 5892    Apr
# Name: Edition_Day, dtype: object

# %%
df_data_corr = df_data.corr()

# %%
df_data_corr
# Out:
#                             Reviews out of 5  Ratings (customer reviews)  \
# Reviews out of 5                    1.000000                   -0.010504
# Ratings (customer reviews)         -0.010504                    1.000000
# Price                               0.108158                   -0.078063
#
#                                Price
# Reviews out of 5            0.108158
# Ratings (customer reviews) -0.078063
# Price                       1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(df_data_corr, annot=True)

# %%
standardize = preprocessing.StandardScaler()

# %%
x = df_data.drop(['Price'],axis=1)
y = df_data['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((4989, 4), (1248, 4), (4989,), (1248,))

# %%
x_train = standardize.fit_transform(x_train)
x_test = standardize.fit_transform(x_test)

# %% [markdown]
# ***Building the model***

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
model = Sequential()

# %%
#1st hidden layer and input layer

# %%
model.add(Dense(output_dim=3, init='uniform', activation='relu', input_dim=4))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=4, units=3, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
#2nd hidden layer

# %%
model.add(Dense(output_dim=3, init='uniform', activation='relu'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=3, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
#3rd hidden layer

# %%
model.add(Dense(output_dim=3, init='uniform', activation='relu'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=3, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
#output layer

# %%
model.add(Dense(output_dim=1, activation='linear'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="linear", units=1)`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 4989/4989 [==============================] - 1s 279us/step - loss: 810024.3510 - mean_absolute_error: 559.3503
# Epoch 2/100
# 4989/4989 [==============================] - 1s 199us/step - loss: 760963.3945 - mean_absolute_error: 517.5370
# Epoch 3/100
# 4989/4989 [==============================] - 1s 202us/step - loss: 616430.1805 - mean_absolute_error: 384.9053
# Epoch 4/100
# 4989/4989 [==============================] - 1s 198us/step - loss: 500545.3515 - mean_absolute_error: 317.9592
# Epoch 5/100
# 4989/4989 [==============================] - 1s 199us/step - loss: 477654.2392 - mean_absolute_error: 338.0904
# Epoch 6/100
# 4989/4989 [==============================] - 1s 211us/step - loss: 475591.5018 - mean_absolute_error: 345.5865
# Epoch 7/100
# 4989/4989 [==============================] - 1s 202us/step - loss: 475209.1018 - mean_absolute_error: 346.4197
# Epoch 8/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 3)                 15
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 4
# ...
# Total params: 43
# Trainable params: 43
# Non-trainable params: 0
# _________________________________________________________________
